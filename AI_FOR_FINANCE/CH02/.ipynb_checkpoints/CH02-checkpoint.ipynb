# %% [markdown]
# # 실습1. 금융 시계열 및 파이썬을 활용한 전통 퀀트 방법 구현

# %%
import FinanceDataReader as fdr
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. 거래소별 전체 종목 코드 수집

# %%
# 한국거래소 상장 종목 가져오기
df_krx = fdr.StockListing('KRX')
df_krx
# Out:
#         Code        ISU_CD      Name Market   Dept    Close ChangeCode  \
# 0     005930  KR7005930003      삼성전자  KOSPI           56800          2
# 1     000660  KR7000660001    SK하이닉스  KOSPI          204500          1
# 2     207940  KR7207940008  삼성바이오로직스  KOSPI         1002000          1
# 3     373220  KR7373220003  LG에너지솔루션  KOSPI          290500          2
# 4     005380  KR7005380001       현대차  KOSPI          193800          1
# ...      ...           ...       ...    ...    ...      ...        ...
# 2874  245450  KR7245450002    씨앤에스링크  KONEX  일반기업부     1200          1
# 2875  288490  KR7288490006     나라소프트  KONEX  일반기업부      105          0
# 2876  236030  KR7236030003      씨알푸드  KONEX  일반기업부      900          1
# 2877  308700  KR7308700004       테크엔  KONEX  일반기업부      199          0
# 2878  217320  KR7217320001       썬테크  KONEX  일반기업부      900          0
#
#       Changes  ChagesRatio     Open     High     Low    Volume        Amount  \
# 0        -500        -0.87    57400    57500   56700  10385352  591058106600
# 1        4000         2.00   206000   206750  203500   2419507  496481724500
# 2        4000         0.40  1000000  1007000  997000     31403   31450547000
# 3      -16500        -5.37   305000   307000  290000    583328  171754453500
# 4         900         0.47   193300   194700  193000    311743   60421466500
# ...       ...          ...      ...      ...     ...       ...           ...
# 2874      101         9.19     1000     1200    1000        21         23100
# 2875        0         0.00        0        0       0         0             0
# 2876      101        12.64      800      900     800        15         12500
# 2877        0         0.00        0        0       0         0             0
# 2878        0         0.00        0        0       0         0             0
#
#                Marcap      Stocks MarketId
# 0     336235433969600  5919637922      STK
# 1     148876483642500   728002365      STK
# 2      71316348000000    71174000      STK
# 3      67977000000000   234000000      STK
# 4      40584857815800   209416191      STK
# ...               ...         ...      ...
# 2874       1895952000     1579960      KNX
# 2875       1834515585    17471577      KNX
# 2876       1829998800     2033332      KNX
# 2877       1472600000     7400000      KNX
# 2878        945000000     1050000      KNX
#
# [2879 rows x 17 columns]

# %%
df_krx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2879 entries, 0 to 2878
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Code         2879 non-null   object
#  1   ISU_CD       2879 non-null   object
#  2   Name         2879 non-null   object
#  3   Market       2879 non-null   object
#  4   Dept         2879 non-null   object
#  5   Close        2879 non-null   object
#  6   ChangeCode   2879 non-null   object
#  7   Changes      2879 non-null   int64
#  8   ChagesRatio  2879 non-null   float64
#  9   Open         2879 non-null   int64
#  10  High         2879 non-null   int64
#  11  Low          2879 non-null   int64
#  12  Volume       2879 non-null   int64
#  13  Amount       2879 non-null   int64
#  14  Marcap       2879 non-null   int64
#  15  Stocks       2879 non-null   int64
#  16  MarketId     2879 non-null   object
# dtypes: float64(1), int64(8), object(8)
# memory usage: 382.5+ KB

# %%
df_krx.columns
# Out:
# Index(['Code', 'ISU_CD', 'Name', 'Market', 'Dept', 'Close', 'ChangeCode',
#        'Changes', 'ChagesRatio', 'Open', 'High', 'Low', 'Volume', 'Amount',
#        'Marcap', 'Stocks', 'MarketId'],
#       dtype='object')

# %%
df_spx = fdr.StockListing('S&P500')
print(len(df_spx))
df_spx
# Out:
# 503
#     Symbol                 Name                  Sector  \
# 0      MMM                   3M             Industrials
# 1      AOS          A. O. Smith             Industrials
# 2      ABT  Abbott Laboratories             Health Care
# 3     ABBV               AbbVie             Health Care
# 4      ACN            Accenture  Information Technology
# ..     ...                  ...                     ...
# 498    XYL           Xylem Inc.             Industrials
# 499    YUM          Yum! Brands  Consumer Discretionary
# 500   ZBRA   Zebra Technologies  Information Technology
# 501    ZBH        Zimmer Biomet             Health Care
# 502    ZTS               Zoetis             Health Care
#
#                                          Industry
# 0                        Industrial Conglomerates
# 1                               Building Products
# 2                           Health Care Equipment
# 3                                   Biotechnology
# 4                  IT Consulting & Other Services
# ..                                            ...
# 498  Industrial Machinery & Supplies & Components
# 499                                   Restaurants
# 500            Electronic Equipment & Instruments
# 501                         Health Care Equipment
# 502                               Pharmaceuticals
#
# [503 rows x 4 columns]

# %% [markdown]
# ## 2. 가격 데이터 수집

# %%
# GS 글로벌(001250), 2018년부터 현재까지
df = fdr.DataReader('001250','2018')
print(df.head(10))
df['Close'].plot()
# Out:
#             Open  High   Low  Close  Volume    Change
# Date
# 2018-01-02  2795  2860  2795   2850  118224  0.019678
# 2018-01-03  2850  2860  2820   2845  152892 -0.001754
# 2018-01-04  2845  2860  2815   2820  195786 -0.008787
# 2018-01-05  2820  2920  2820   2900  283369  0.028369
# 2018-01-08  2900  2940  2870   2900  179173  0.000000
# 2018-01-09  2920  2945  2860   2875  209231 -0.008621
# 2018-01-10  2850  2970  2850   2955  440681  0.027826
# 2018-01-11  2975  2975  2930   2940  200819 -0.005076
# 2018-01-12  2930  2955  2890   2910  156725 -0.010204
# 2018-01-15  2910  2915  2870   2895  245777 -0.005155
# <Axes: xlabel='Date'>

# %%
aapl_df = fdr.DataReader('AAPL','2000')
aapl_df['Close'].plot()
# Out:
# <Axes: >

# %% [markdown]
# # PANDAS
# ### 1. shift() : 데이터 프레임이나 시리즈의 데이터를 위 아래로 이동

# %%
aapl_df['Close_lag1'] = aapl_df['Close'].shift()
aapl_df.head()
# Out:
#                 Open      High       Low     Close     Volume  Adj Close  \
# 1999-12-31  0.901228  0.918527  0.888393  0.917969  163811200   0.772487
# 2000-01-03  0.936384  1.004464  0.907924  0.999442  535796800   0.841048
# 2000-01-04  0.966518  0.987723  0.903460  0.915179  512377600   0.770139
# 2000-01-05  0.926339  0.987165  0.919643  0.928571  778321600   0.781408
# 2000-01-06  0.947545  0.955357  0.848214  0.848214  767972800   0.713787
#
#             Close_lag1
# 1999-12-31         NaN
# 2000-01-03    0.917969
# 2000-01-04    0.999442
# 2000-01-05    0.915179
# 2000-01-06    0.928571

# %% [markdown]
# ### 2. pct_change() : 시리즈 또는 데이터프레임의 요소 간의 백분율 변화를 계산

# %%
aapl_df['pct_change'] = aapl_df['Close'].pct_change()
aapl_df.head(20)
# Out:
#                 Open      High       Low     Close      Volume  Adj Close  \
# 1999-12-31  0.901228  0.918527  0.888393  0.917969   163811200   0.772487
# 2000-01-03  0.936384  1.004464  0.907924  0.999442   535796800   0.841048
# 2000-01-04  0.966518  0.987723  0.903460  0.915179   512377600   0.770139
# 2000-01-05  0.926339  0.987165  0.919643  0.928571   778321600   0.781408
# 2000-01-06  0.947545  0.955357  0.848214  0.848214   767972800   0.713787
# 2000-01-07  0.861607  0.901786  0.852679  0.888393   460734400   0.747598
# 2000-01-10  0.910714  0.912946  0.845982  0.872768   505064000   0.734449
# 2000-01-11  0.856585  0.887277  0.808036  0.828125   441548800   0.696881
# 2000-01-12  0.848214  0.852679  0.772321  0.778460   976068800   0.655087
# 2000-01-13  0.843610  0.881696  0.825893  0.863839  1032684800   0.726935
# 2000-01-14  0.892857  0.912946  0.887277  0.896763   390376000   0.754641
# 2000-01-18  0.901786  0.946429  0.896763  0.928013   459177600   0.780939
# 2000-01-19  0.943080  0.970982  0.922991  0.951451   597643200   0.800662
# 2000-01-20  1.031250  1.084821  1.013393  1.013393  1831132800   0.852788
# 2000-01-21  1.020089  1.020089  0.983817  0.993862   495924800   0.836352
# 2000-01-24  0.968192  1.006696  0.938616  0.948661   440876800   0.798314
# 2000-01-25  0.937500  1.010045  0.914063  1.002232   497145600   0.843395
# 2000-01-26  0.982143  1.019531  0.979911  0.983817   367158400   0.827899
# 2000-01-27  0.971540  1.008929  0.955357  0.982143   340144000   0.826490
# 2000-01-28  0.965960  0.989955  0.898438  0.907366   423348800   0.763564
#
#             Close_lag1  pct_change
# 1999-12-31         NaN         NaN
# 2000-01-03    0.917969    0.088754
# 2000-01-04    0.999442   -0.084310
# 2000-01-05    0.915179    0.014633
# 2000-01-06    0.928571   -0.086538
# 2000-01-07    0.848214    0.047369
# 2000-01-10    0.888393   -0.017588
# 2000-01-11    0.872768   -0.051151
# 2000-01-12    0.828125   -0.059973
# 2000-01-13    0.778460    0.109677
# 2000-01-14    0.863839    0.038114
# 2000-01-18    0.896763    0.034848
# 2000-01-19    0.928013    0.025256
# 2000-01-20    0.951451    0.065103
# 2000-01-21    1.013393   -0.019273
# 2000-01-24    0.993862   -0.045480
# 2000-01-25    0.948661    0.056470
# 2000-01-26    1.002232   -0.018374
# 2000-01-27    0.983817   -0.001702
# 2000-01-28    0.982143   -0.076137

# %% [markdown]
# ### 3. rolling() : 이동평균이나 이동 표준편차 같은 이동 통계를 계산하는데 사용
# * 괄호 안에 7을 넣으면 7일 이동평균 구할 수 있음

# %%
aapl_df['rolling7'] = aapl_df['Close'].rolling(window='7')
aapl_df.head(20)
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "offsets.pyx", line 4855, in pandas._libs.tslibs.offsets.to_offset
# ValueError: last element must be blank
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\이정호\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\window\rolling.py", line 1881, in _validate
#     freq = to_offset(self.window)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "offsets.pyx", line 4791, in pandas._libs.tslibs.offsets.to_offset
#   File "offsets.pyx", line 4954, in pandas._libs.tslibs.offsets.to_offset
# ValueError: Invalid frequency: 7, failed to parse with error message: ValueError('last element must be blank')
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\이정호\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\interactiveshell.py", line 3460, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\이정호\AppData\Local\Temp\ipykernel_18936\3386447416.py", line 1, in <module>
#     aapl_df['rolling7'] = aapl_df['Close'].rolling(window='7')
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\이정호\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py", line 12580, in rolling
#     return Rolling(
#            ^^^^^^^^
#   File "C:\Users\이정호\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\window\rolling.py", line 170, in __init__
#     self._validate()
#   File "C:\Users\이정호\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\window\rolling.py", line 1883, in _validate
#     raise ValueError(
# ValueError: passed window 7 is not compatible with a datetimelike index
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\이정호\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\interactiveshell.py", line 2057, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\이정호\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\ultratb.py", line 1288, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\이정호\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\ultratb.py", line 1177, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\이정호\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\ultratb.py", line 1049, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\이정호\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\ultratb.py", line 935, in format_exception_as_a_whole
#     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\이정호\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\ultratb.py", line 1003, in get_records
#     lines, first = inspect.getsourcelines(etb.tb_frame)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\이정호\AppData\Local\Programs\Python\Python311\Lib\inspect.py", line 1244, in getsourcelines
#     lines, lnum = findsource(object)
#                   ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\이정호\AppData\Local\Programs\Python\Python311\Lib\inspect.py", line 1081, in findsource
#     raise OSError('could not get source code')
# OSError: could not get source code

# %%
import pandas as pd
from pandas_datareader import data as pdr
import talib
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 2
#       1 import pandas as pd
# ----> 2 from pandas_datareader import data as pdr
#       3 import talib
#
# ModuleNotFoundError: No module named 'pandas_datareader'

# %%
# 이후 파이낸스에서 애플의 주식 데이터를 불러온다.
aapl_data = pdr.get_data_yahoo('AAPL')

# 단순이동평균 (SMA)을 계산한다. 여기서는 20일 SMA를 계산한다.
aapl_data['SMA_20'] = talib.SMA(aapl_data['Close'], timeperiod=20)

# 상대강도지수(RSI)를 계산한다. 여기서는 14일 RSI를 계산한다.
aapl_data['RSI_14'] = talib.RSI(aapl_data['Close'], timeperiod=14)

# 결과를 출력한다.
print(aapl_data.tail())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 # 이후 파이낸스에서 애플의 주식 데이터를 불러온다.
# ----> 2 aapl_data = pdr.get_data_yahoo('AAPL')
#       4 # 단순이동평균 (SMA)을 계산한다. 여기서는 20일 SMA를 계산한다.
#       5 aapl_data['SMA_20'] = talib.SMA(aapl_data['Close'], timeperiod=20)
#
# NameError: name 'pdr' is not defined

# %%
import yfinance as yf

aapl_data = yf.download("AAPL", start="2020-01-01", end="2025-05-01")
print(aapl_data.head())
# Out:
# YF.download() has changed argument auto_adjust default to True
# Failed to get ticker 'AAPL' reason: Failed to perform, curl: (77) error setting certificate verify locations:  CAfile: C:\Users\이정호\AppData\Local\Programs\Python\Python311\Lib\site-packages\certifi\cacert.pem CApath: none. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAPL']: SSLError('Failed to perform, curl: (77) error setting certificate verify locations:  CAfile: C:\\Users\\이정호\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\certifi\\cacert.pem CApath: none. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.')
# Empty DataFrame
# Columns: [(Adj Close, AAPL), (Close, AAPL), (High, AAPL), (Low, AAPL), (Open, AAPL), (Volume, AAPL)]
# Index: []
